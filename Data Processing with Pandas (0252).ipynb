# %% [markdown]
# # Hafsa Rani

# %% [markdown]
# # Reg no # 0252

# %% [markdown]
# # Assingment no#3 : Data Processing with Pandas

# %% [markdown]
# # The dataset shall be cleaned through the following processes

# %% [markdown]
# 1. Checking the number of columns
# 2. Changing misplelt column names to the correct names
# 3. Checking for missing values
# 4. Checking for duplicate values
# 5. Checking for outliers

# %%
import pandas as pd

# Read the CSV dataset into a DataFrame
df = pd.read_csv('aug_test.csv')

# Print the DataFrame
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.head() #Top record of the dataset
# Out:
#    enrollee_id      city  city_development_index  gender  \
# 0        32403   city_41                   0.827    Male
# 1         9858  city_103                   0.920  Female
# 2        31806   city_21                   0.624    Male
# 3        27385   city_13                   0.827    Male
# 4        27724  city_103                   0.920    Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience    Full time course        Graduate
# 1  Has relevent experience       no_enrollment        Graduate
# 2   No relevent experience       no_enrollment     High School
# 3  Has relevent experience       no_enrollment         Masters
# 4  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM          9          <10          NaN            1
# 1             STEM          5          NaN      Pvt Ltd            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             2129 non-null   int64
#  1   city                    2129 non-null   object
#  2   city_development_index  2129 non-null   float64
#  3   gender                  1621 non-null   object
#  4   relevent_experience     2129 non-null   object
#  5   enrolled_university     2098 non-null   object
#  6   education_level         2077 non-null   object
#  7   major_discipline        1817 non-null   object
#  8   experience              2124 non-null   object
#  9   company_size            1507 non-null   object
#  10  company_type            1495 non-null   object
#  11  last_new_job            2089 non-null   object
#  12  training_hours          2129 non-null   int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 216.4+ KB

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours
# count   2129.000000             2129.000000     2129.000000
# mean   16861.614843                0.824984       64.983091
# std     9576.846029                0.125074       60.238660
# min        3.000000                0.448000        1.000000
# 25%     8562.000000                0.698000       23.000000
# 50%    16816.000000                0.903000       47.000000
# 75%    25129.000000                0.920000       86.000000
# max    33353.000000                0.949000      334.000000

# %%
df.columns  #Checking for number of columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours'],
#       dtype='object')

# %%
#Rename the colunmns  "company_size" to "size_company"
df.rename(columns={"company_size" : "size_company"}, inplace=True)

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'size_company', 'company_type',
#        'last_new_job', 'training_hours'],
#       dtype='object')

# %%
df.isnull().sum()        #check missing values
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                    508
# relevent_experience         0
# enrolled_university        31
# education_level            52
# major_discipline          312
# experience                  5
# size_company              622
# company_type              634
# last_new_job               40
# training_hours              0
# dtype: int64

# %%
#replace the missing values in the  columns "enrollee_id "
mean_value = df["enrollee_id"].mean()
mean_value
# Out:
# 16861.61484264913

# %%
#using the mean value to replace the missing records

df["enrollee_id"].fillna(mean_value,inplace=True)

# %%
#to confirm the change
df.isnull().sum()
# Out:
# enrollee_id                 0
# city                        0
# city_development_index      0
# gender                    508
# relevent_experience         0
# enrolled_university        31
# education_level            52
# major_discipline          312
# experience                  5
# size_company              622
# company_type              634
# last_new_job               40
# training_hours              0
# dtype: int64

# %% [markdown]
# # Handling Missing Data (Dropena )

# %%
df.dropna()           #drop along row
# Out:
#       enrollee_id      city  city_development_index gender  \
# 3           27385   city_13                   0.827   Male
# 4           27724  city_103                   0.920   Male
# 11           9272   city_90                   0.698   Male
# 12          14249   city_46                   0.762   Male
# 16           7865   city_21                   0.624   Male
# ...           ...       ...                     ...    ...
# 2113        10726   city_71                   0.884   Male
# 2115        13833   city_21                   0.624   Male
# 2117        21500   city_44                   0.725   Male
# 2121        27163  city_173                   0.878   Male
# 2128        12215  city_102                   0.804   Male
#
#           relevent_experience enrolled_university education_level  \
# 3     Has relevent experience       no_enrollment         Masters
# 4     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.shape
# Out:
# (2129, 13)

# %%
df.dropna().shape
# Out:
# (1019, 13)

# %%
df.dropna(how='all').shape
# Out:
# (2129, 13)

# %% [markdown]
# # axis=1 used to drop values along columns

# %%
df.dropna(axis=1)
# Out:
#       enrollee_id      city  city_development_index      relevent_experience  \
# 0           32403   city_41                   0.827  Has relevent experience
# 1            9858  city_103                   0.920  Has relevent experience
# 2           31806   city_21                   0.624   No relevent experience
# 3           27385   city_13                   0.827  Has relevent experience
# 4           27724  city_103                   0.920  Has relevent experience
# ...           ...       ...                     ...                      ...
# 2124         1289  city_103                   0.920   No relevent experience
# 2125          195  city_136                   0.897  Has relevent experience
# 2126        31762  city_100                   0.887   No relevent experience
# 2127         7873  city_102                   0.804  Has relevent experience
# 2128        12215  city_102                   0.804  Has relevent experience
#
#       training_hours
# 0                 21
# ...

# %% [markdown]
# # axis=0 used to drop values   along rows

# %%
df.dropna(axis=0)
# Out:
#       enrollee_id      city  city_development_index gender  \
# 3           27385   city_13                   0.827   Male
# 4           27724  city_103                   0.920   Male
# 11           9272   city_90                   0.698   Male
# 12          14249   city_46                   0.762   Male
# 16           7865   city_21                   0.624   Male
# ...           ...       ...                     ...    ...
# 2113        10726   city_71                   0.884   Male
# 2115        13833   city_21                   0.624   Male
# 2117        21500   city_44                   0.725   Male
# 2121        27163  city_173                   0.878   Male
# 2128        12215  city_102                   0.804   Male
#
#           relevent_experience enrolled_university education_level  \
# 3     Has relevent experience       no_enrollment         Masters
# 4     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.dropna(subset=["major_discipline"])                   #particular colnum ky along null values remove kr skty hin
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# 5             217   city_23                   0.899    Male
# ...           ...       ...                     ...     ...
# 2121        27163  city_173                   0.878    Male
# 2122        24507   city_90                   0.698     NaN
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.groupby('gender')['gender'].agg("count")
# Out:
# gender
# Female     137
# Male      1460
# Other       24
# Name: gender, dtype: int64

# %%
df.groupby('education_level')['education_level'].agg("count")
# Out:
# education_level
# Graduate          1269
# High School        222
# Masters            496
# Phd                 54
# Primary School      36
# Name: education_level, dtype: int64

# %%
#check unique vales in columns "relevent_experience"
df["relevent_experience"].unique()
# Out:
# array(['Has relevent experience', 'No relevent experience'], dtype=object)

# %% [markdown]
# # what is outlier?

# %% [markdown]
#  An outlier is a data point in a data set that is distant from all other observation. A data point that lies outside  the overall distribution of the data set.

# %% [markdown]
# # Handling Missing Data (fillna)

# %%
import pandas as pd

# Read the CSV dataset into a DataFrame
df = pd.read_csv('aug_test.csv')

# Print the DataFrame
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.fillna("Hafsa")        # fill missing values with "hafsa"
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df['company_size'].fillna(40)
# Out:
# 0           <10
# 1            40
# 2            40
# 3         10/49
# 4        10000+
#          ...
# 2124         40
# 2125         40
# 2126         40
# 2127    100-500
# 2128     10000+
# Name: company_size, Length: 2129, dtype: object

# %%
df['company_size'].fillna(method='ffill')
# Out:
# 0           <10
# 1           <10
# 2           <10
# 3         10/49
# 4        10000+
#          ...
# 2124        <10
# 2125        <10
# 2126        <10
# 2127    100-500
# 2128     10000+
# Name: company_size, Length: 2129, dtype: object

# %%
import matplotlib.pyplot as plt

# Create a histogram of the agu_testin the DataFrame
plt.hist(df["relevent_experience"])
plt.xlabel("relevent_experience")
plt.ylabel("experience")
plt.title("aug_test")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a scatterplot with 'gender' on both axes
sns.scatterplot(x='gender', y='gender', data=df)
plt.xlabel('Gender')
plt.ylabel('Gender')
plt.title('Gender Scatterplot')
plt.show()
